# %% [markdown]
# ## PROJECT ON PYTHON

# %% [markdown]
# ## Import all libraries needed

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load the data into pandas dataframe:
# #Loading the data into the pandas data frame. So all we have to do is to just read the CSV into a data frame.
# #Reading the data before preprocessing.

# %%
df_employee = pd.read_csv("C:\\Users\\sgkur\\myexcel - myexcel.csv.csv")
df_employee
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# # PREPROCESSING:
# #Correcting the data in the "height" column by replacing it with random numbers between 150 and 180.

# %%
import pandas as pd
import random

# Replace "height" column with random values between 150 and 180
df_employee['Height'] = [random.randint(150, 180) for _ in range(len(df_employee))]

print(df_employee)
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     158     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     154     235
# 2     John Holland  Boston Celtics      30       SG   27     150     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     161     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     171     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     166     203
# 454      Raul Neto       Utah Jazz      25       PG   24     173     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     176     256
# 456    Jeff Withey       Utah Jazz      24        C   26     161     231
# 457       Priyanka       Utah Jazz      34        C   25     159     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df_employee.head()
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25     168     180
# 1    Jae Crowder  Boston Celtics      99       SF   25     179     235
# 2   John Holland  Boston Celtics      30       SG   27     152     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22     161     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29     152     231
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
df_employee.tail()
# Out:
#              Name       Team  Number Position  Age  Height  Weight College  \
# 453  Shelvin Mack  Utah Jazz       8       PG   26     168     203  Butler
# 454     Raul Neto  Utah Jazz      25       PG   24     169     179     NaN
# 455  Tibor Pleiss  Utah Jazz      21        C   26     153     256     NaN
# 456   Jeff Withey  Utah Jazz      24        C   26     156     231  Kansas
# 457      Priyanka  Utah Jazz      34        C   25     157     231  Kansas
#
#         Salary
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457   947276.0

# %% [markdown]
# ## DATA CLEANING AND DATA ANALYSING:
#
# Using the following steps we can clean oue data.
#
# 1.Understanding the data using describe,info and shape functions.
# 2.Handling missing data
# 3.Checking duplicates
# 4.Checking data types
# 5.Checking outliers using data visualization
# 6.Checking invalid data(Date/height)
# 7.Checking the integrity of data.
#
# Data cleaning refers to the process of removing unwanted variables and values from our dataset and getting rid of any irregularities in it.Such irregularities can disproportionality skew our data and hence adversely effect the result. Gaining general knowledge about the data—including its values, kinds, number of rows and columns, and missing values—is the primary objective of data understanding.

# %%
#1.Understanding the Data:
df_employee.describe()

#statistical summary of the data set which gives the count, mean, standard deviation, minimum,
#and quartiles for each numerical column. The dataset’s central tendencies and spread are briefly summarized.
# Out:
#            Number         Age      Height      Weight        Salary
# count  458.000000  458.000000  458.000000  458.000000  4.470000e+02
# mean    17.713974   26.934498  165.242358  221.543668  4.833970e+06
# std     15.966837    4.400128    9.198527   26.343200  5.226620e+06
# min      0.000000   19.000000  150.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  157.000000  200.000000  1.025210e+06
# 50%     13.000000   26.000000  165.500000  220.000000  2.836186e+06
# 75%     25.000000   30.000000  173.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  180.000000  307.000000  2.500000e+07

# %%
df_employee.info()

#facilitates comprehension of the data type and related information, such as the quantity of records in each column,
#whether the data is null or not, the type of data, and the dataset’s memory usage.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    int64
#  6   Weight    458 non-null    int64
#  7   College   374 non-null    object
#  8   Salary    447 non-null    float64
# dtypes: float64(1), int64(4), object(4)
# memory usage: 32.3+ KB

# %%
df_employee.shape

#shape will show how many features and observations there are in the dataset.
# Out:
# (458, 9)

# %% [markdown]
# ## 2.Handling missing data
# #identify missing data using isnull() function.

# %%
df_employee.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %% [markdown]
# ## Finding missing data by dropping rows/columns using dropna()function.
# #Handling missing data by fillna() function.

# %%
df1= df_employee.dropna()
df1.count()
# Out:
# Name        365
# Team        365
# Number      365
# Position    365
# Age         365
# Height      365
# Weight      365
# College     365
# Salary      365
# dtype: int64

# %%
df_employee.fillna(df_employee.Salary.mean())
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College        Salary
# 0                Texas  7.730337e+06
# ...

# %%
df_employee['College'].fillna('Missing')
# Out:
# 0                  Texas
# 1              Marquette
# 2      Boston University
# 3          Georgia State
# 4                Missing
#              ...
# 453               Butler
# 454              Missing
# 455              Missing
# 456               Kansas
# 457               Kansas
# Name: College, Length: 458, dtype: object

# %% [markdown]
# # 3.Checking duplicates.
#
# #Detecting duplicates using duplicated() function.

# %%
df_employee.duplicated().sum() #0 duplicates.
# Out:
# 0

# %%
#Checking repeated or redunted data
#Summarizes the uniqueness of all columns in the data set.

df_employee.nunique()
# Out:
# Name        458
# Team         30
# Number       53
# Position      5
# Age          22
# Height       18
# Weight       87
# College     118
# Salary      309
# dtype: int64

# %% [markdown]
# ## 4.Checking data types.

# %%
df_employee.dtypes
# Out:
# Name         object
# Team         object
# Number        int64
# Position     object
# Age           int64
# Height       object
# Weight        int64
# College      object
# Salary      float64
# dtype: object

# %% [markdown]
# ## 5.Checking outliers.
# An outlier  is a data point that significantly deviates from the majority of the dataset. It is an observation that lies outside
# the expected range or distribution, often because of variability in the data, measurement errors, or anomalies.
#
# Characteristics of Outliers:
# They are far from the mean or median of the data.
# They can skew statistical analyses, leading to misleading results.
# Identifying and handling outliers is critical in data preprocessing to ensure accurate model performance.

# %%
import pandas as pd
import random
import matplotlib.pyplot as plt
import seaborn as sns

# Box plot for the height of employees
plt.figure(figsize=(8, 6))
sns.boxplot(
    df_employee['Height'], 
    vert=True, 
    patch_artist=True, 
    boxprops=dict(facecolor="lightgreen", color="darkgreen"),
    whiskerprops=dict(color="blue", linestyle="--"),
    capprops=dict(color="purple"),
    medianprops=dict(color="red", linewidth=2),
    flierprops=dict(marker="o", color="orange", markersize=8)
)
plt.title("Box Plot of Employee Heights at ABC Company", fontsize=14, color="darkblue")
plt.ylabel("Height (cm)", fontsize=12, color="darkred")
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:700: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   artists = ax.bxp(**boxplot_kws)

# %% [markdown]
# ## Determine the distribution of employees across each team and calculate the percentage split relative to the total number of employees.

# %%
df_employee["Team"].nunique()#no of unique values in team
# Out:
# 30

# %%
df_employee["Team"].unique()
# Out:
# array(['Boston Celtics', 'Brooklyn Nets', 'New York Knicks',
#        'Philadelphia 76ers', 'Toronto Raptors', 'Golden State Warriors',
#        'Los Angeles Clippers', 'Los Angeles Lakers', 'Phoenix Suns',
#        'Sacramento Kings', 'Chicago Bulls', 'Cleveland Cavaliers',
#        'Detroit Pistons', 'Indiana Pacers', 'Milwaukee Bucks',
#        'Dallas Mavericks', 'Houston Rockets', 'Memphis Grizzlies',
#        'New Orleans Pelicans', 'San Antonio Spurs', 'Atlanta Hawks',
#        'Charlotte Hornets', 'Miami Heat', 'Orlando Magic',
#        'Washington Wizards', 'Denver Nuggets', 'Minnesota Timberwolves',
#        'Oklahoma City Thunder', 'Portland Trail Blazers', 'Utah Jazz'],
#       dtype=object)

# %%
df_employee["Team"].value_counts()
# Out:
# Team
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# Utah Jazz                 16
# New York Knicks           16
# Milwaukee Bucks           16
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Boston Celtics            15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Dallas Mavericks          15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: count, dtype: int64

# %%
# Create the plot
import seaborn as sns

plt.figure(figsize=(20,6))
plt.xticks(rotation=45)
plt.xlabel('Team')
plt.ylabel(count)
sns.countplot(x ='Team',data = df_employee,hue = 'Team',palette = 'plasma')
plt.title('Distribution of Employees Across Each  Team',fontsize=14, color="darkblue")
plt.show()

# %% [markdown]
# ## How many are there in each Team and the percentage splitting with respect to the total employees.

# %%
no_team =30
total_employee =458
team = pd.Series(df_employee["Team"].value_counts())
percentage =(team/total_employee)*100
result = pd.concat([team,percentage.round(2)],axis=1,keys = ["no of employee","percentage"])
result
# Out:
#                         no of employee  percentage
# Team
# New Orleans Pelicans                19        4.15
# Memphis Grizzlies                   18        3.93
# Utah Jazz                           16        3.49
# New York Knicks                     16        3.49
# Milwaukee Bucks                     16        3.49
# Brooklyn Nets                       15        3.28
# Portland Trail Blazers              15        3.28
# Oklahoma City Thunder               15        3.28
# Denver Nuggets                      15        3.28
# Washington Wizards                  15        3.28
# Miami Heat                          15        3.28
# Charlotte Hornets                   15        3.28
# Atlanta Hawks                       15        3.28
# San Antonio Spurs                   15        3.28
# Houston Rockets                     15        3.28
# Boston Celtics                      15        3.28
# Indiana Pacers                      15        3.28
# ...

# %% [markdown]
# DATA STORY:
# The countplot analysis based on the employees in each team reveals that"new orlean pelican" team has heighest number of employees that is 19 and closely followed by "Memphis Grizzilies" as 18. Majority of the teams are having 15 employees.

# %% [markdown]
# ## Segregate employees based on their positions within the company.

# %%
df_employee["Position"].value_counts()
# Out:
# Position
# SG    102
# PF    100
# PG     92
# SF     85
# C      79
# Name: count, dtype: int64

# %%
df_employee[df_employee["Position"]=="PG"]
# Out:
#               Name                    Team  Number Position  Age    Date  \
# 0    Avery Bradley          Boston Celtics       0       PG   25  06-Feb
# 8     Terry Rozier          Boston Celtics      12       PG   22  06-Feb
# 9     Marcus Smart          Boston Celtics      36       PG   22  06-Apr
# 11   Isaiah Thomas          Boston Celtics       4       PG   27  05-Sep
# 19    Jarrett Jack           Brooklyn Nets       2       PG   32  06-Mar
# ..             ...                     ...     ...      ...  ...     ...
# 440  Brian Roberts  Portland Trail Blazers       2       PG   30  06-Jan
# 443     Trey Burke               Utah Jazz       3       PG   23  06-Jan
# 445     Dante Exum               Utah Jazz      11       PG   20  06-Jun
# 453   Shelvin Mack               Utah Jazz       8       PG   26  06-Mar
# 454      Raul Neto               Utah Jazz      25       PG   24  06-Jan
#
#      Weight         College     Salary  height
# ...

# %%
df_employee[df_employee["Position"]=="SG"]
# Out:
#                  Name                    Team  Number Position  Age  Height  \
# 2        John Holland          Boston Celtics      30       SG   27     150
# 3         R.J. Hunter          Boston Celtics      28       SG   22     161
# 12        Evan Turner          Boston Celtics      11       SG   27     162
# 13        James Young          Boston Celtics      13       SG   20     165
# 15   Bojan Bogdanovic           Brooklyn Nets      44       SG   27     173
# ..                ...                     ...     ...      ...  ...     ...
# 433  Gerald Henderson  Portland Trail Blazers       9       SG   28     153
# 437     C.J. McCollum  Portland Trail Blazers       3       SG   24     174
# 438      Luis Montero  Portland Trail Blazers      44       SG   23     177
# 444        Alec Burks               Utah Jazz      10       SG   24     161
# 449       Rodney Hood               Utah Jazz       5       SG   23     158
#
#      Weight            College     Salary
# ...

# %%
#grouping employees by position
grp_position = df_employee.groupby("Position")
for position, group in grp_position:
    print(f"position:{position}")
    print(group[["Name","Position"]])
    print("\n")
# Out:
# position:C
#                 Name Position
# 7       Kelly Olynyk        C
# 10   Jared Sullinger        C
# 14      Tyler Zeller        C
# 23       Brook Lopez        C
# 27        Henry Sims        C
# ..               ...      ...
# 439    Mason Plumlee        C
# 447      Rudy Gobert        C
# 455     Tibor Pleiss        C
# 456      Jeff Withey        C
# 457         Priyanka        C
#
# [79 rows x 2 columns]
#
#
# position:PF
#                  Name Position
# 4       Jonas Jerebko       PF
# 5        Amir Johnson       PF
# 6       Jordan Mickey       PF
# 24   Chris McCullough       PF
# 25        Willie Reed       PF
# ..                ...      ...
# 435    Meyers Leonard       PF
# 441       Noah Vonleh       PF
# 442     Trevor Booker       PF
# 446    Derrick Favors       PF
# 452        Trey Lyles       PF
#
# [100 rows x 2 columns]
#
#
# position:PG
#               Name Position
# 0    Avery Bradley       PG
# 8     Terry Rozier       PG
# ...

# %%
positions = df_employee["Position"].unique()
print("unique positions :",positions)
plt.figure(figsize=(8,6))
plt.title("Employee Count By Position")
sns.countplot(x = "Position",data = df_employee,hue="Position",palette = "dark")
# Out:
# unique positions : ['PG' 'SF' 'SG' 'PF' 'C']
# <Axes: title={'center': 'Employee Count By Position'}, xlabel='Position', ylabel='count'>

# %% [markdown]
# DATA STORY:
# According to countplot analysis: In SG position there were morethan 100 employees (approx:103) and closely followed by PF position ,ie,100 employees others are having less number of employees.

# %% [markdown]
# ## Identify the predominant age group among employees.

# %%
df_employee["Age"]
# Out:
# 0      25
# 1      25
# 2      27
# 3      22
# 4      29
#        ..
# 453    26
# 454    24
# 455    26
# 456    26
# 457    25
# Name: Age, Length: 458, dtype: int64

# %%
 df_employee["Age"].unique()
# Out:
# array([25, 22, 21, 24, 27, 20, 26, 28, 32, 23, 30, 33, 29, 31, 36, 38, 19,
#        35, 34, 37, 39, 40], dtype=int64)

# %%
df_employee["Age"].nunique()
# Out:
# 22

# %%
df_employee["Age"].value_counts()
# Out:
# Age
# 25    42
# 24    41
# 27    35
# 23    33
# 26    32
# 28    27
# 22    23
# 30    20
# 29    17
# 31    17
# 20    15
# 21    14
# 36     9
# 32     9
# 33     8
# 35     7
# 34     7
# 38     3
# 19     2
# 40     2
# 37     1
# 39     1
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the figure size
plt.figure(figsize=(10, 5))

# Create the countplot with a vibrant palette
sns.countplot(
    x="Age", 
    data=df_employee,
    hue="Age",
    palette="viridis",  # Use a vibrant palette
    saturation=0.8      # Enhance color intensity
)

# Add a title and labels
plt.title("Count of Employees by Age", fontsize=14, fontweight='bold')
plt.xlabel("Age", fontsize=10)
plt.ylabel("Count", fontsize=10)

# Customize the ticks for better visibility
plt.xticks(fontsize=10, rotation=45)
plt.yticks(fontsize=10)

# Display the plot
plt.show()

# %% [markdown]
# DATA STORY:
# Largest number of employees(42) arecoming under the age group of 25.
# 41 employees are coming under the age group of 24.
# Two employees are there in the age group of 19 and 40.
# Only one employee each in 39 and 37 age group.

# %%
import warnings
import sys
if not sys.warnoptions:
    warnings.simplefilter("ignore")

df_employee['Age Group'] = df_employee['Age'].apply(lambda age:'20-25' if 20 <= age <= 25
                                                    else ('26-30' if 26 <= age <= 30
                                                          else ('31-35' if 31 <= age <= 35
                                                                else '36 -40')))
df_employee
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     158     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     154     235
# 2     John Holland  Boston Celtics      30       SG   27     150     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     161     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     171     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     166     203
# 454      Raul Neto       Utah Jazz      25       PG   24     173     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     176     256
# 456    Jeff Withey       Utah Jazz      24        C   26     161     231
# 457       Priyanka       Utah Jazz      34        C   25     159     231
#
#                College     Salary Age Group
# 0                Texas  7730337.0     20-25
# ...

# %%
df_employee["Age Group"].value_counts()
# Out:
# Age Group
# 20-25     198
# 26-30     167
# 31-35      68
# 36 -40     25
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.countplot(x="Age Group",data = df_employee,palette = "magma",hue = "Age Group")

# Add a title and labels
plt.title("Age Group of Employees", fontsize=14, fontweight='bold')
plt.xlabel("Age Group", fontsize=10)
plt.ylabel("Count", fontsize=10)

# Customize the ticks for better visibility
plt.xticks(fontsize=10, rotation=45)
plt.yticks(fontsize=10)

# Display the plot
plt.show()

# %% [markdown]
# DATA STORY:
# The highest number of employees (198) are coming under the age group 20-25.
# The lowest number of employees (25)are coming under the age group 36-40.

# %% [markdown]
# ## Discover which team and position have the highest salary expenditure.

# %%
import warnings
import sys
if not sys.warnoptions:
    warnings.simplefilter("ignore")
    
x = df_employee["Salary"].mean()
df_employee["Salary"].fillna(x,inplace =True)
df_employee
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     158     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     154     235
# 2     John Holland  Boston Celtics      30       SG   27     150     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     161     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     171     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     166     203
# 454      Raul Neto       Utah Jazz      25       PG   24     173     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     176     256
# 456    Jeff Withey       Utah Jazz      24        C   26     161     231
# 457       Priyanka       Utah Jazz      34        C   25     159     231
#
#                College        Salary Age Group
# ...

# %%
df_employee["Salary"].value_counts()
# Out:
# Salary
# 9.472760e+05    32
# 8.450590e+05    18
# 5.250930e+05    13
# 4.833970e+06    11
# 9.813480e+05     6
#                 ..
# 2.100000e+06     1
# 1.252440e+06     1
# 2.891760e+06     1
# 3.272091e+06     1
# 9.000000e+05     1
# Name: count, Length: 310, dtype: int64

# %%
df2 = df_employee[["Name","Team","Position","Salary"]]
df2
# Out:
#               Name            Team Position        Salary
# 0    Avery Bradley  Boston Celtics       PG  7.730337e+06
# 1      Jae Crowder  Boston Celtics       SF  6.796117e+06
# 2     John Holland  Boston Celtics       SG  4.833970e+06
# 3      R.J. Hunter  Boston Celtics       SG  1.148640e+06
# 4    Jonas Jerebko  Boston Celtics       PF  5.000000e+06
# ..             ...             ...      ...           ...
# 453   Shelvin Mack       Utah Jazz       PG  2.433333e+06
# 454      Raul Neto       Utah Jazz       PG  9.000000e+05
# 455   Tibor Pleiss       Utah Jazz        C  2.900000e+06
# 456    Jeff Withey       Utah Jazz        C  9.472760e+05
# 457       Priyanka       Utah Jazz        C  9.472760e+05
#
# [458 rows x 4 columns]

# %%
#find maxmum salary
total_salary = df2.groupby(["Team","Position"])["Salary"].sum()
max_spending = total_salary.idxmax()
max_spending_salary = total_salary.max()
print(f"The team and position with the highest spending is:\n"
          f"Team: {max_spending[0]}\n"
          f"Position: {max_spending[1]}\n"
          f"With a total salary of {max_spending_salary}.")
# Out:
# The team and position with the highest spending is:
# Team: Los Angeles Lakers
# Position: SF
# With a total salary of 31866445.0.

# %%
plt.figure(figsize=(20,5))
sns.scatterplot(y = "Salary",x="Team",hue = "Position",data = df_employee)
plt.ylabel("Salary",fontsize=10)
plt.xlabel("Team",fontsize=10)
plt.title("Scatter Plot- Position VS Team With Salary",fontsize=14, fontweight='bold')
plt.xticks(rotation=90)

plt.grid(axis='y')# Adding grid for better analysis

plt.show()

# %% [markdown]
# DATA STORY:
# Scatter plot gives salary distribution across different position within each team.This shows thatthe 'SF' position in the team 'Los Angeles Lakers' has the highest salary,
# follwed by the 'SF' position in 'NewYork Knicks,Cleaveland Cavaliers.

# %% [markdown]
# ## Investigate if there's any correlation between age and salary, and represent it visually.

# %% [markdown]
# CORRELATION:
#
# Values close to +1 indicates strong positive correlation, -1 indicates a strong negative correlation and 0 indicates suggests no linear correlation. Darker colors signify strong correlation, while light colors represents weaker correlations. Positive correlation variable move in same directions. As one increases, the other also increases. Negative correlation variable move in opposite directions. An increase in one variable is associated with a decrease in the other.HEAT MAPSMaps
#
# Heat Maps is a type of plot which is necessary when we need to find the dependent variables. One of the best way to find the relationship between the features can be done using hea.mapsIn

# %%
df3 = df_employee[["Age","Salary"]]
df3
# Out:
#      Age        Salary
# 0     25  7.730337e+06
# 1     25  6.796117e+06
# 2     27  4.833970e+06
# 3     22  1.148640e+06
# 4     29  5.000000e+06
# ..   ...           ...
# 453   26  2.433333e+06
# 454   24  9.000000e+05
# 455   26  2.900000e+06
# 456   26  9.472760e+05
# 457   25  9.472760e+05
#
# [458 rows x 2 columns]

# %%
#Compute correlation
corr = df3.corr()
corr
# Out:
#             Age   Salary
# Age     1.00000  0.21117
# Salary  0.21117  1.00000

# %%
#Create Heat Map
sns.heatmap(corr,annot=True,cmap="coolwarm")
#Add tittle
plt.title("Correlation Matrix Between Age And Salary Of Employees")
#Show plot
plt.show()

# %% [markdown]
# DATA STORY :
# The heatmap provides actionable insights by quantifying the strength and direction of relationships, with annotations highlighting exact correlation values and a color gradient visually reinforcing these trends.
#
# Key Findings from the Heatmap
# Age vs. Salary:
#
# A strong positive correlation (e.g., 0.7 or above) between Age and Salary indicates that employees with more years of experience or seniority earn higher salaries. This is often typical in organizations with hierarchical pay scales where tenure plays a significant role in compensation.
#
# A weak or negligible correlation (e.g., close to 0) would suggest that salary is not significantly influenced by age. This could reflect modern compensation strategies focused on meritocracy or skill-based pay rather than tenure.

# %% [markdown]
# SUMMARY:
# In summary, the Python-based  data analysis of the employee in" ABC COMPANY" dataset has yielded important new information about the properties of the sample. Investigated correlations between variables, identified outliers, and obtained a knowledge of the distribution of important features using statistical summaries and visualizations. The quantitative and qualitative features of the dataset were analyzed in detail through the use of various plots, including bar, box, and heat map plots. Furthermore, the analysis demonstrated the ability to visualize and analyze complicated datasets using Python tools such as Matplotlib, Seaborn, and Pandas. The results provide a thorough grasp of the dataset.
